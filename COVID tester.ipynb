# %%
import pandas as pd

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    fever  bodyPain  age  runnyNose  diffBreath  tiredness  chestPain  \
# 0    101         1   74          0           0          1          0
# 1    100         1   84          1           1          0          1
# 2    104        -1   26          1          -1          0          0
# 3    108        -1   45          1          -1          0          0
# 4     98         0   53          0           1          1         -1
#
#    dryMouth  breathHold  infectionProb
# 0         0          15              0
# 1         0           8              1
# 2         1          16              0
# 3         1           9              0
# 4         1          10              0

# %%
df.tail()
# Out:
#       fever  bodyPain  age  runnyNose  diffBreath  tiredness  chestPain  \
# 2494    101        -1   19          0           0          1          0
# 2495     99        -1    3          1          -1         -1          1
# 2496     98         0   66          0          -1          0          1
# 2497    102         0   30          0          -1          0         -1
# 2498    104         0   91          0          -1          1         -1
#
#       dryMouth  breathHold  infectionProb
# 2494         0           7              0
# 2495         0           4              1
# 2496         1          14              0
# 2497         0           3              1
# 2498         0          20              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fever          2499 non-null   int64
#  1   bodyPain       2499 non-null   int64
#  2   age            2499 non-null   int64
#  3   runnyNose      2499 non-null   int64
#  4   diffBreath     2499 non-null   int64
#  5   tiredness      2499 non-null   int64
#  6   chestPain      2499 non-null   int64
#  7   dryMouth       2499 non-null   int64
#  8   breathHold     2499 non-null   int64
#  9   infectionProb  2499 non-null   int64
# dtypes: int64(10)
# memory usage: 195.4 KB

# %%
df['diffBreath'].value_counts()
# Out:
#  0    842
# -1    831
#  1    826
# Name: diffBreath, dtype: int64

# %%
df.describe()
# Out:
#              fever     bodyPain          age    runnyNose   diffBreath  \
# count  2499.000000  2499.000000  2499.000000  2499.000000  2499.000000
# mean    103.014006     0.009204    50.819928     0.503802    -0.002001
# std       3.739651     0.815382    29.113201     0.500086     0.814449
# min      97.000000    -1.000000     1.000000     0.000000    -1.000000
# 25%     100.000000    -1.000000    25.000000     0.000000    -1.000000
# 50%     103.000000     0.000000    52.000000     1.000000     0.000000
# 75%     106.000000     1.000000    76.000000     1.000000     1.000000
# max     109.000000     1.000000   100.000000     1.000000     1.000000
#
#          tiredness    chestPain     dryMouth   breathHold  infectionProb
# count  2499.000000  2499.000000  2499.000000  2499.000000    2499.000000
# mean     -0.017207    -0.008003     0.512205    12.236495       0.492597
# std       0.821123     0.819557     0.499951     5.589193       0.500045
# ...

# %% [markdown]
# ## Train Test Splitting

# %%
import numpy as np

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
np.random.permutation(7)
# Out:
# array([4, 2, 6, 5, 0, 1, 3])

# %%
train, test = data_split(df, 0.2)

# %%
train
# Out:
#       fever  bodyPain  age  runnyNose  diffBreath  tiredness  chestPain  \
# 461     108        -1   84          1           1          0         -1
# 109     103         0   82          0           0          0          1
# 2296    100        -1   42          1          -1          0          0
# 354     106         0   60          0           1         -1         -1
# 266     103         1   18          1          -1         -1          0
# ...     ...       ...  ...        ...         ...        ...        ...
# 1638    101        -1   78          0           1          0          1
# 1095    103        -1   67          0           0         -1          1
# 1130     99         1    4          1           1          0          0
# 1294    106         0   93          1           0          1          0
# 860     104         1   49          0           1          1          0
#
#       dryMouth  breathHold  infectionProb
# 461          1          20              1
# ...

# %%
test
# Out:
#       fever  bodyPain  age  runnyNose  diffBreath  tiredness  chestPain  \
# 2319     98         0   38          1          -1          0         -1
# 1865    101        -1   78          0           0          1          1
# 902     108         1   67          1          -1          0          0
# 2240     97        -1   74          1           1          0         -1
# 1285    101        -1   96          0           1         -1          1
# ...     ...       ...  ...        ...         ...        ...        ...
# 1037    107         1   31          1           0          1          0
# 2054    106         1   84          0           1         -1          1
# 1860    105        -1   19          0           0          0         -1
# 1862    102         1    8          0           1          1          1
# 1151    107         1   42          1           1          1         -1
#
#       dryMouth  breathHold  infectionProb
# 2319         1           7              1
# ...

# %%
X_train = train[['fever', 'bodyPain', 'age', 'runnyNose', 'diffBreath', 'tiredness', 'chestPain', 'dryMouth', 'breathHold']].to_numpy()
X_test = test[['fever', 'bodyPain', 'age', 'runnyNose', 'diffBreath', 'tiredness', 'chestPain', 'dryMouth', 'breathHold']].to_numpy()

# %%
Y_train = train[['infectionProb']].to_numpy().reshape(2000 ,)
Y_test = test[['infectionProb']].to_numpy().reshape(499 ,)

# %%
Y_train
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
inputFeatures = [102, 1, 22, -1, 1, 1, -1, 1, 5]
infProb =clf.predict_proba([inputFeatures])[0][1]

# %%
infProb
# Out:
# 0.4684879242250779
